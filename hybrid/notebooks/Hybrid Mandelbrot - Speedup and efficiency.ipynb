# %% [markdown]
# # Openmp Mandelbrot - Speedup and efficiency plotting

# %% [markdown]
# ### Imports

# %%
from operator import truediv
from matplotlib.pylab import plt

# %% [markdown]
# ### Obtain speedup and efficiency

# %%
threads = [1,2,4,8,16]

# %%
def get_speedup(filename):
    data = [[float(n) for n in line.strip().split('\t')] for line in open(filename, 'r').readlines()]
    serial = data[0]
    data = data[1:]
    speedup = list(zip(*[list(map(truediv, serial, row)) for row in data]))[1:]
    
    return speedup

def get_efficiency(speedup):
    return [list(map(truediv, row, threads)) for row in speedup]

# %% [markdown]
# ### Plot speedup and efficiency for each process

# %%
legend = ["size: 600x400 iterations: 10⁴", "size: 3000x2000 iterations: 10⁴", 
          "size: 6000x4000 iterations: 10⁴", "size: 30000x20000 iterations: 10⁴",
          "size: 600x400 iterations: 10⁵", "size: 3000x2000 iterations: 10⁵", 
          "size: 6000x4000 iterations: 10⁵", "size: 30000x20000 iterations: 10⁵",
          "size: 600x400 iterations: 10⁶", "size: 3000x2000 iterations: 10⁶", 
          "size: 6000x4000 iterations: 10⁶", "size: 30000x20000 iterations: 10⁶"]

# %%
def plot_speedup(speedup):    
    # %matplotlib inline
    
    plt.figure(figsize=(30,30))
    
    for i in range(0, len(speedup)):
        plt.plot(threads, speedup[i], label='$y = {i}x + {i}$'.format(i=i))
        
    plt.xlim(1, 16)
    plt.xlabel('Number of threads', fontsize=30)
    plt.ylim(1.0, 8)
    plt.ylabel('Speedup', fontsize=30)
    plt.legend(legend, loc='lower right', prop={'size': 30})
    plt.show()
    
def plot_efficiency(efficiency):
    # %matplotlib inline
    
    plt.figure(figsize=(30,30))
    
    for i in range(0, len(efficiency)):
        plt.plot(threads, efficiency[i], label='$y = {i}x + {i}$'.format(i=i))
        
    plt.xlim(1, 16)
    plt.xlabel('Number of threads', fontsize=30)
    plt.ylim(0.0, 1.0)
    plt.ylabel('Efficiency', fontsize=30)
    plt.legend(legend, loc='upper right', prop={'size': 30})
    plt.show()

# %% [markdown]
# ### Static design
# #### Speedup for 2 processes

# %%
speedup_static_p2 = get_speedup("traces/speedup_static_p2.txt")
plot_speedup(speedup_static_p2)

# %%
plot_efficiency(get_efficiency(speedup_static_p2))

# %% [markdown]
# #### Speedup for 4 processes

# %%
speedup_static_p4 = get_speedup("traces/speedup_static_p4.txt")
plot_speedup(speedup_static_p4)

# %%
plot_efficiency(get_efficiency(speedup_static_p4))

# %% [markdown]
# #### Speedup for 8 processes

# %%
speedup_static_p8 = get_speedup("traces/speedup_static_p8.txt")
plot_speedup(speedup_static_p8)

# %%
plot_efficiency(get_efficiency(speedup_static_p8))

# %% [markdown]
# #### Speedup for 16 processes

# %%
speedup_static_p16 = get_speedup("traces/speedup_static_p16.txt")
plot_speedup(speedup_static_p16)

# %%
plot_efficiency(get_efficiency(speedup_static_p16))

# %% [markdown]
# ### Dynamic design
# #### Speedup for 2 processes

# %%
speedup_dynamic_p2 = get_speedup("traces/speedup_dynamic_p2.txt")
plot_speedup(speedup_dynamic_p2)

# %%
plot_efficiency(get_efficiency(speedup_dynamic_p2))

# %% [markdown]
# #### Speedup for 4 processes

# %%
speedup_dynamic_p4 = get_speedup("traces/speedup_dynamic_p4.txt")
plot_speedup(speedup_dynamic_p4)

# %%
plot_efficiency(get_efficiency(speedup_dynamic_p4))

# %% [markdown]
# #### Speedup for 8 processes

# %%
speedup_dynamic_p8 = get_speedup("traces/speedup_dynamic_p8.txt")
plot_speedup(speedup_dynamic_p8)

# %%
plot_efficiency(get_efficiency(speedup_dynamic_p8))

# %% [markdown]
# #### Speedup for 16 processes

# %%
speedup_dynamic_p16 = get_speedup("traces/speedup_dynamic_p16.txt")
plot_speedup(speedup_dynamic_p16)

# %%
plot_efficiency(get_efficiency(speedup_dynamic_p16))
